# %%
import numpy as np
import sympy
from sympy import symbols, Eq, linear_eq_to_matrix
import random
import matplotlib.pyplot as plt
from collections import deque, defaultdict
# from pyeda.inter import expr, exprvar, expr2bdd
# from dd.autoref import BDD
import networkx as nx
from matplotlib.colors import ListedColormap
import itertools
import pandas as pd
from sympy.logic.boolalg import SOPform
import re
import pickle
import datetime
import time
import scipy.sparse as sp
import scipy.sparse.linalg as spla
from itertools import product
import seaborn as sns
from collections import deque


# change the code to save the data in sqlite database or pickle file to store the results
    # store number of devices in each path
    # Store currents in each path for future plots

#make code run in hipergator

#run upto 3-bit adder for optimal solution with 10 iterations and generate graphs

#############################################################################

#find and pinpoint cases that get only max zeros and min ones current

# 1 - (number of devices)
# 0 - (neighbour lrs devices to ground)
# run the simulation for only those special cases
import sys
import os
import importlib

# %%
# Insert the parent directory (one level up) into sys.path:
parent_dir = os.path.abspath("..")  # or an explicit path to the parent
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

# First import the module in a normal way:
import PathDesignGeneration

# Whenever you make changes in PathVerification.py (where PATH is defined),
# run these two lines to reload the module:
importlib.reload(PathDesignGeneration)
from PathDesignGeneration import PATH

# %%
# Insert the parent directory (one level up) into sys.path:
parent_dir = os.path.abspath("..")  # or an explicit path to the parent
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

# First import the module in a normal way:
import PathDesignGeneration

# Whenever you make changes in PathVerification.py (where PATH is defined),
# run these two lines to reload the module:
importlib.reload(PathDesignGeneration)
from PathDesignGeneration import PATH


lst= [1,4,8,16,32]
path_design_lst = []

filename_lst = {str(i)+"-bitMultiplexer":"../bdds/Multiplexer/"+str(i)+"-bitMultiplexer.sbdd" for i in lst}
# with open("Data/truth_tables_data.pkl", "rb") as f:
#     truth_tables_data = pickle.load(f)

Functional_Logic_Of_Path_Crossbar_Programings = {}
nadder = 1
for adderbit in lst:
    start_time = time.time()
    adder_index = adderbit-1
    filename = filename_lst[str(adderbit)+'-bitMultiplexer']

    # if(adderbit<10):
    #     outputs, df = truth_tables_data[str(adderbit)+'-bitAdder']["outputs"], truth_tables_data[str(adderbit)+'-bitAdder']["TruthTable_df"]
    # else:
    #     outputs, df = None, None
        
    path = PATH(CrossbarGridSize = 128)
    # path.TruthTable_to_BooleanExpression(df, outputs=outputs)
    # path.BooleanExpresions_to_BDD()
    # print("----------------------------------------------------------------------------------------------")
    # expressions = {'F0' : '(a & b) | (a & cin) | (b & cin)',
    # 'F1' : '(a & b & cin) | (a & ~b & ~cin) | (b & ~a & ~cin) | (cin & ~a & ~b)'}
    # variables = ['a', 'b', 'cin']
    # path.SetBooleanExpressionsAndVaribles(variables = variables, expressions = expressions, outputs = list(expressions.keys()))
    # print("----------------------------------------------------------------------------------------------")
    
    # path.SetBooleanExpressionsAndVaribles(variables = None, expressions = None, outputs = outputs, OriginalTruthTable=df)
    path.parse_file_to_NetworkXGraph(filename)
    path.BDD_to_NetworkXGraph()
    # if(adderbit<5):
    #     path.Verify_BDD_to_NetworkXGraph(withExpression=False, withOriginalTruthTable=False, generateFromBDD=True)
    # path.VisuvaliseNetworkXGraph()
    # print("----------------------------------------------------------------------------------------------")
    path.GraphPreprocessing()
    # if(adderbit==1):
    #     path.VisuvaliseNetworkXGraph()
    # print("----------------------------------------------------------------------------------------------")
    path.GraphTransformation()
    # path.VisuvaliseNetworkXGraph(bipartite=True)
    # print("----------------------------------------------------------------------------------------------")
    path.GraphCompression()
    # if(adderbit==1):
    #     path.VisuvaliseNetworkXGraph(bipartite=True)
    # print("----------------------------------------------------------------------------------------------")

    # path.GraphSplittingWithHeightConstraint(height=10)
    path.GraphSplittingWithHeightConstraint(height=40)

    # path.GraphAddRootNodeToInputLines()

    # path.GraphSplittinWithSizeConstraint(size=64)
    path.GraphSplittinWithSizeConstraint(size=128)
    
    path.CrossbarDesignRelalization()

    path_design_lst.append(path)

    # path.InferPrerequisiteTrees()

    # print('path.Processed_graphs_Map', path.Processed_graphs_Map.keys())

    # print('path.Processed_graphs_Map[None]',path.Processed_graphs_Map[None])

    # print('path.output_node_index',path.output_node_index)

    # rows, cols, count = 0, 0, 0
    # dimMap = {}
    # for key in path.Processed_graphs_Map:
    #     row = len(path.Processed_graphs_Map[key]['Crossbar_design'])
    #     col = len(path.Processed_graphs_Map[key]['Crossbar_design'][0])

    #     if(f'{row}x{col}' not in dimMap):
    #         dimMap[f'{row}x{col}'] = 0
    #     dimMap[f'{row}x{col}']+=1
    #     rows+=row
    #     cols+=col
    #     count+=1

    # print('Total = rows x cols:', rows,"x", cols, "count:", count)
    # print(dimMap)

    # Functional_Logic_Of_Path_Crossbar_Programings[str(adderbit)+'-bitAdder'] = {'Crossbar':path.CrossbarResistiveStates, 'Bitlines':path.Bitlines, 'TruthTable':path.OriginalTruthTable, 'OutputLine_Map':path.OutputLine_Map, 'AdderBit':str(adderbit)+'-bitAdder', 'SBDD (V x E)':path.SBDD_dimentions}
    
    print(f"{adderbit}-bit Adder took {time.time() - start_time:.6f} seconds")

    # print('path.CrossbarLongPaths',path.CrossbarLongPaths)
    print("_________________________________________________________________________")
    # if(adderbit==nadder):
    #     break

# Save (pickle) to a file
# with open("Data/Functional_Logic_Of_Path_Crossbar_Programings.pkl", "wb") as f:
#     pickle.dump(Functional_Logic_Of_Path_Crossbar_Programings, f)
# print("Data saved to multi_data.pkl")
# Out:
# 1-bit Adder took 0.000997 seconds
# _________________________________________________________________________
# 4-bit Adder took 0.002036 seconds
# _________________________________________________________________________
# 8-bit Adder took 0.003975 seconds
# _________________________________________________________________________
# 16-bit Adder took 0.006007 seconds
# _________________________________________________________________________
# 32-bit Adder took 0.012477 seconds
# _________________________________________________________________________

# %%
for path in path_design_lst:
    print(path.Topological_order)
# Out:
# [(frozenset(), 0)]
# [(frozenset(), 0)]
# [(frozenset(), 0)]
# [(frozenset(), 0)]
# [(frozenset(), 0)]

# %%
for design_ID_group in path.Processed_group_graphs_Map:
    print()
    print(path.Processed_group_graphs_Map[design_ID_group].keys())
    print(sorted(path.Processed_group_graphs_Map[design_ID_group]['OutputLine_group_Map'].keys()))
    print(sorted(path.Processed_group_graphs_Map[design_ID_group]['OutputLine_group_selectorLines_Map'].keys()))
    print(path.Processed_group_graphs_Map[design_ID_group]['OutputLine_group_selectorLines_Map'])
# Out:
# dict_keys(['processed_group_graph', 'OutputLine_group_Map', 'OutputLine_group_selectorLines_Map', 'BDD_dimentions', 'Selector_Lines_Map', 'Crossbar_design', 'DesignIdItemToWordLineInputMap', 'LongestPaths', 'Crossbar_disabledOutputsToInputs'])
# ['O0']
# ['O0']
# {'O0': [43, 4, 29, 80, 90, 5, 57, 3, 99, 28, 98, 42, 27, 78, 22, 19, 13, 8, 111, 44, 85, 50, 36, 34, 10, 106, 15, 75, 51, 64, 66, 95, 108, 21, 11, 39, 71, 92, 52, 77, 83, 82, 33, 23, 20, 68, 94, 67, 102, 38, 97, 45, 9, 14, 105, 81, 37, 53, 62, 65, 24, 112, 41, 70, 47, 74, 7, 103, 79, 109, 12, 30, 49, 86, 0, 16, 100, 91, 6, 32, 107, 1, 110, 18, 104, 89, 55, 88, 61, 58, 56, 60, 69, 26, 40, 87, 54, 63, 72, 73, 35, 93, 17, 59, 2, 46, 96, 76, 25, 101, 48, 31, 84]}

# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import defaultdict, deque

def plot_tree_bfs_layered(G, node_labels=True, edge_labels=False, title="Tree (BFS Layered Plot)", debug=False):
    # Step 1: Find the root node (U1 node with no predecessors)
    # Step 1: Find all root nodes (U1 nodes with no predecessors)
    roots = [
        node for node in G.nodes
        if G.nodes[node].get("BipartitePart") == "U1" and G.in_degree(node) == 0
    ]
    if not roots:
        raise ValueError("No root nodes found (U1 nodes with no predecessors)")

    # Step 2: BFS from all roots to assign levels
    levels = {root: 0 for root in roots}
    layer_nodes = defaultdict(list)
    queue = deque(roots)

    for root in roots:
        layer_nodes[0].append(root)

    while queue:
        node = queue.popleft()
        level = levels[node]

        for succ in G.successors(node):
            if succ not in levels:
                levels[succ] = level + 1
                layer_nodes[level + 1].append(succ)
                queue.append(succ)

    # Step 3: Assign positions
    pos = {}
    x_gap = 2.5
    y_gap = 1.5
    for level, nodes in layer_nodes.items():
        for i, node in enumerate(nodes):
            pos[node] = (i * x_gap, -level * y_gap)

    # Step 4: Assign positions to unplaced nodes (unreachable from root)
    unplaced_nodes = [node for node in G.nodes if node not in pos]
    if unplaced_nodes:
        extra_level = max(layer_nodes.keys(), default=0) + 1
        for i, node in enumerate(unplaced_nodes):
            pos[node] = (i * x_gap, -extra_level * y_gap)

    # Step 5: Determine node colors
    node_colors = []
    for node in G.nodes:
        if node in unplaced_nodes:
            node_colors.append('red')
        else:
            literal = G.nodes[node].get('literal', '')
            in_split_ids = G.nodes[node].get('in_split_id',set())
            out_split_id = G.nodes[node].get('out_split_id',None)
            if(in_split_ids != set()):
                if(debug):
                    print(literal, 'in_split_ids',in_split_ids)
            if(out_split_id != None):
                if(debug):
                    print(literal, 'out_split_id',out_split_id)
            if out_split_id != None:
                node_colors.append('purple')
            elif len(in_split_ids)>0:
                node_colors.append('lime')
            elif 'O' in literal:
                node_colors.append('orange')
            elif literal.isdigit():
                node_colors.append('grey')
            else:
                node_colors.append('lightblue')

    # Step 6: Draw the graph
    plt.figure(figsize=(12, 6))
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=800)
    nx.draw_networkx_edges(G, pos, arrows=True, arrowstyle='->', arrowsize=20)

    if node_labels:
        labels = {n: G.nodes[n].get('literal', str(n)) for n in G.nodes}
        nx.draw_networkx_labels(G, pos, labels, font_size=10)

    if edge_labels:
        edge_lbls = {(u, v): d.get('condition', '') for u, v, d in G.edges(data=True)}
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_lbls, font_size=8)

    plt.title(title)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

for path in path_design_lst:
    for i,key in enumerate(path.Processed_group_graphs_Map):
        # if(i not in [2,4,5,7,9,10,11,12]):
        #     continue
        # for row in path.Processed_graphs_Map[key]['Crossbar_design']:
        #     print(row)
        # print(path.Processed_graphs_Map[key]['Selector_Lines_Map'])
        # print(key, i)
        # print(path.Processed_group_graphs_Map[key]['OutputLine_group_Map'])
        # print(key)
        if(i!=0):
            continue
        plot_tree_bfs_layered(
            path.Processed_group_graphs_Map[key]['processed_group_graph'],
            debug=True
        )

# %%
# First import the module in a normal way:
import PathDesignLogicalVerification

# Whenever you make changes in PathVerification.py (where PATH is defined),
# run these two lines to reload the module:
importlib.reload(PathDesignLogicalVerification)
from PathDesignLogicalVerification import PATH_Design_Logic_Verification, Bus

for node in path.Processed_group_graphs_Map:
    # for row in path.Processed_graphs_Map[node]['Crossbar_design']:
    #     print(row)
    # print(path.Processed_graphs_Map[node]['Selector_Lines_Map'])
    # print(path.Processed_graphs_Map[node]['OutputLine_Map'])
    # print()
    # print(path.Processed_graphs_Map[node]['BDD_dimentions'])
    # print(path.Processed_graphs_Map[node]['LongestPath'])
    # print(path.Processed_graphs_Map[node]['DesignIdItemToWordLineInputMap'])
    # print(path.Processed_graphs_Map[node]['PrerequisiteTrees'])
    print('------------------------------------------------')

CrossbarGridSize = 128

for path in path_design_lst:

    bus = Bus(MainBDD_For_GoldenModel = path.Graph, Topological_order = path.Topological_order)
    
    total_rows = 0
    total_cols = 0
    Processed_group_graphs_Map = {}
    for design_ID in path.Processed_group_graphs_Map:
        m = len(path.Processed_group_graphs_Map[design_ID]['Crossbar_design'])
        n = len(path.Processed_group_graphs_Map[design_ID]['Crossbar_design'][0])
        if(total_rows+m <= CrossbarGridSize and total_cols+n <= CrossbarGridSize):
            Processed_group_graphs_Map[design_ID] = path.Processed_group_graphs_Map[design_ID]
            total_rows += m
            total_cols += n
        else:
            path_functional_verification = PATH_Design_Logic_Verification(bus, Processed_group_graphs_Map, CrossbarGridSize=CrossbarGridSize)
            Processed_group_graphs_Map = {design_ID: path.Processed_group_graphs_Map[design_ID]}
    if(len(Processed_group_graphs_Map)):
        path_functional_verification = PATH_Design_Logic_Verification(bus, Processed_group_graphs_Map, CrossbarGridSize=CrossbarGridSize)
    
    print('NumberOfDesigns:', bus.getNumberOfDesigns())
    print('NumberOfCrossbars:', bus.getNumberOfCrossbars())
    
    test_results = bus.RunRandomTestCases(num_tests=4, RunAllTests=False)
    print('----------------------------------------------')


# OutputLine_group_selectorLines_Map
# Out:
# ------------------------------------------------
# NumberOfDesigns: 1
# NumberOfCrossbars: 1
# ______________________________________
# [✅] Test 1 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 0}
# ______________________________________
# Number of test cases passed out of is 4/4
# ----------------------------------------------
# NumberOfDesigns: 1
# NumberOfCrossbars: 1
# ______________________________________
# [✅] Test 1 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 1}
# ______________________________________
# Number of test cases passed out of is 4/4
# ----------------------------------------------
# NumberOfDesigns: 1
# NumberOfCrossbars: 1
# ______________________________________
# [✅] Test 1 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 1}
# ______________________________________
# Number of test cases passed out of is 4/4
# ----------------------------------------------
# NumberOfDesigns: 1
# NumberOfCrossbars: 1
# ______________________________________
# [✅] Test 1 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 0}
# ______________________________________
# Number of test cases passed out of is 4/4
# ----------------------------------------------
# NumberOfDesigns: 1
# NumberOfCrossbars: 1
# ______________________________________
# [✅] Test 1 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 1}
# ______________________________________
# Number of test cases passed out of is 4/4
# ----------------------------------------------

# %%
# First import the module in a normal way:
import PathDesignAnalogVerification

# Whenever you make changes in PathVerification.py (where PATH is defined),
# run these two lines to reload the module:
importlib.reload(PathDesignAnalogVerification)
from PathDesignAnalogVerification import PATH_Design_Analog_Verification, Bus

for node in path.Processed_group_graphs_Map:
    # for row in path.Processed_graphs_Map[node]['Crossbar_design']:
    #     print(row)
    # print(path.Processed_graphs_Map[node]['Selector_Lines_Map'])
    # print(path.Processed_graphs_Map[node]['OutputLine_Map'])
    # print()
    # print(path.Processed_graphs_Map[node]['BDD_dimentions'])
    # print(path.Processed_graphs_Map[node]['LongestPath'])
    # print(path.Processed_graphs_Map[node]['DesignIdItemToWordLineInputMap'])
    # print(path.Processed_graphs_Map[node]['PrerequisiteTrees'])
    print('------------------------------------------------')

bus_lst = []

for path in path_design_lst:
    CrossbarGridSize = 128
    bus = Bus(MainBDD_For_GoldenModel = path.Graph, Topological_order = path.Topological_order)
    total_rows = 0
    total_cols = 0
    Processed_group_graphs_Map = {}
    for design_ID in path.Processed_group_graphs_Map:
        m = len(path.Processed_group_graphs_Map[design_ID]['Crossbar_design'])
        n = len(path.Processed_group_graphs_Map[design_ID]['Crossbar_design'][0])
        if(total_rows+m <= CrossbarGridSize and total_cols+n <= CrossbarGridSize):
            Processed_group_graphs_Map[design_ID] = path.Processed_group_graphs_Map[design_ID]
            total_rows += m
            total_cols += n
        else:
            path_analog_verification = PATH_Design_Analog_Verification(bus, Processed_group_graphs_Map, CrossbarGridSize=CrossbarGridSize)
            Processed_group_graphs_Map = {design_ID: path.Processed_group_graphs_Map[design_ID]}
            total_rows = m
            total_cols = n
    if(len(Processed_group_graphs_Map)):
        path_analog_verification = PATH_Design_Analog_Verification(bus, Processed_group_graphs_Map, CrossbarGridSize=CrossbarGridSize)

    # bus.CalibrateHRSValues(Optimisation=True, max_iterations=1)
    bus.setHRSValues(HRSvalue=8e6)

    bus_lst.append(bus)
# Out:
# ------------------------------------------------

# %%
CurrentFlow0 = []
CurrentFlow1 = []

durations = []

for bus in bus_lst:

    start_time = time.time()
    # test_results = bus.RunRandomTestCases(num_tests=40, RunAllTests=True)
    test_results = bus.RunRandomTestCases(num_tests=100, RunAllTests=False)
    
    failuresOfWorstcase0 = 0
    failuresOfWorstcase1 = 0
    
    currentFlag = False
    for design_ID in bus.OnesCurrentFromDesignMap:
        minOnesCurrent = min(bus.OnesCurrentFromDesignMap[design_ID],default=1)
        maxZerosCurrent = max(bus.ZerosCurrentFromDesignMap[design_ID],default=0)
        print()
        print(f"maxZerosCurrent: {maxZerosCurrent}")
        print(f"minOnesCurrent : {minOnesCurrent}")
        
        CurrentFlow0.append(maxZerosCurrent)
        CurrentFlow1.append(minOnesCurrent)
        
        # if(maxZerosCurrent-bus.WorstCaseMaxZero[design_ID]>1e-4):
        #     print(f"Worst case approximation is not working 0 for {design_ID}")
        #     print(f"{bus.WorstCaseMaxZero[design_ID]} < {maxZerosCurrent}")
        #     print("worst max 0 < current") 
        #     failuresOfWorstcase0+=1
        
        # if(bus.WorstCaseMinOne[design_ID]-minOnesCurrent>1e-4):
        #     print(f"Worst case approximation is not working 1 for {design_ID}")
        #     print(f"{bus.WorstCaseMinOne[design_ID]} > {minOnesCurrent}")
        #     print("worst min 1 > current")
        #     failuresOfWorstcase1+=1
        
        if(minOnesCurrent<maxZerosCurrent):
            currentFlag = True
            print(f'Have an issue at {design_ID}')
    
    if(currentFlag):
        print("\nNot good 😡")
    else:
        print("\ngood 😁")

    end_time = time.time()
    durations.append(end_time-start_time)
# Out:
# total_combinations 8
# ______________________________________
# [✅] Test 1 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 5 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 6 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 7 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 8 Passed {'out': 1}
# ______________________________________
# Number of test cases passed out of is 8/8
#
# maxZerosCurrent: 0.0021743020505818507
# minOnesCurrent : 0.03866509747253849
#
# good 😁
# total_combinations 64
# ______________________________________
# [✅] Test 1 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 5 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 6 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 7 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 8 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 9 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 10 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 11 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 12 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 13 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 14 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 15 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 16 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 17 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 18 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 19 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 20 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 21 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 22 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 23 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 24 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 25 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 26 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 27 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 28 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 29 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 30 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 31 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 32 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 33 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 34 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 35 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 36 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 37 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 38 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 39 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 40 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 41 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 42 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 43 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 44 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 45 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 46 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 47 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 48 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 49 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 50 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 51 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 52 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 53 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 54 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 55 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 56 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 57 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 58 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 59 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 60 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 61 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 62 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 63 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 64 Passed {'out': 1}
# ______________________________________
# Number of test cases passed out of is 64/64
#
# maxZerosCurrent: 0.005513187081116799
# minOnesCurrent : 0.028638476695792735
#
# good 😁
# total_combinations 2048
# ______________________________________
# [✅] Test 1 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 5 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 6 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 7 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 8 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 9 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 10 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 11 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 12 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 13 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 14 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 15 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 16 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 17 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 18 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 19 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 20 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 21 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 22 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 23 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 24 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 25 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 26 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 27 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 28 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 29 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 30 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 31 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 32 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 33 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 34 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 35 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 36 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 37 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 38 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 39 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 40 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 41 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 42 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 43 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 44 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 45 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 46 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 47 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 48 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 49 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 50 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 51 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 52 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 53 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 54 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 55 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 56 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 57 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 58 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 59 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 60 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 61 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 62 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 63 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 64 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 65 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 66 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 67 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 68 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 69 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 70 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 71 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 72 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 73 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 74 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 75 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 76 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 77 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 78 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 79 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 80 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 81 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 82 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 83 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 84 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 85 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 86 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 87 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 88 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 89 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 90 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 91 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 92 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 93 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 94 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 95 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 96 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 97 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 98 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 99 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 100 Passed {'out': 1}
# ______________________________________
# Number of test cases passed out of is 100/100
#
# maxZerosCurrent: 0.011000332410566178
# minOnesCurrent : 0.02043576931185838
#
# good 😁
# total_combinations 1048576
# ______________________________________
# [✅] Test 1 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 5 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 6 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 7 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 8 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 9 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 10 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 11 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 12 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 13 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 14 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 15 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 16 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 17 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 18 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 19 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 20 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 21 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 22 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 23 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 24 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 25 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 26 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 27 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 28 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 29 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 30 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 31 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 32 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 33 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 34 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 35 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 36 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 37 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 38 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 39 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 40 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 41 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 42 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 43 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 44 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 45 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 46 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 47 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 48 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 49 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 50 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 51 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 52 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 53 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 54 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 55 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 56 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 57 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 58 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 59 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 60 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 61 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 62 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 63 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 64 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 65 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 66 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 67 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 68 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 69 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 70 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 71 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 72 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 73 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 74 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 75 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 76 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 77 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 78 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 79 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 80 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 81 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 82 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 83 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 84 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 85 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 86 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 87 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 88 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 89 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 90 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 91 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 92 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 93 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 94 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 95 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 96 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 97 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 98 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 99 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 100 Passed {'out': 0}
# ______________________________________
# Number of test cases passed out of is 100/100
#
# maxZerosCurrent: 0.01570741493025514
# minOnesCurrent : 0.018549167673518285
#
# good 😁
# total_combinations 137438953472
# ______________________________________
# [✅] Test 1 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 2 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 3 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 4 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 5 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 6 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 7 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 8 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 9 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 10 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 11 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 12 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 13 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 14 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 15 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 16 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 17 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 18 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 19 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 20 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 21 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 22 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 23 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 24 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 25 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 26 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 27 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 28 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 29 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 30 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 31 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 32 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 33 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 34 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 35 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 36 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 37 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 38 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 39 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 40 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 41 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 42 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 43 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 44 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 45 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 46 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 47 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 48 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 49 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 50 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 51 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 52 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 53 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 54 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 55 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 56 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 57 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 58 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 59 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 60 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 61 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 62 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 63 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 64 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 65 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 66 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 67 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 68 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 69 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 70 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 71 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 72 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 73 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 74 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 75 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 76 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 77 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 78 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 79 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 80 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 81 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 82 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 83 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 84 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 85 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 86 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 87 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 88 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 89 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 90 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 91 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 92 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 93 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 94 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 95 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 96 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 97 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 98 Passed {'out': 0}
# ______________________________________
# ______________________________________
# [✅] Test 99 Passed {'out': 1}
# ______________________________________
# ______________________________________
# [✅] Test 100 Passed {'out': 0}
# ______________________________________
# Number of test cases passed out of is 100/100
#
# maxZerosCurrent: 0.019691560443609743
# minOnesCurrent : 0.018947519060086272
# Have an issue at (frozenset(), 0)
#
# Not good 😡

# %%
durations
# Out:
# [0.45395493507385254,
#  3.9115495681762695,
#  6.44202446937561,
#  6.431525468826294,
#  6.73505973815918]

# %%
durations_plot = durations.copy()
durations_plot[0] = durations_plot[0]
durations_plot[1] = durations_plot[1]
durations_plot[2] = (durations_plot[2]/100)*2048
durations_plot[3] = (durations_plot[3]/100)*1048576
durations_plot[4] = (durations_plot[4]/100)*137438953472

# %%
log()

# %%
failuresOfWorstcase0, failuresOfWorstcase1
# Out:
# (0, 0)

# %%
number_of_inputs = [3, 6, 11, 20, 37]
max_path_length = [6, 8, 10, 12, 14]

# %%
from matplotlib.lines import Line2D
from matplotlib.patches import FancyArrowPatch


# X-axis categories
x = ['mux2_1', 'mux4_1', 'mux8_1', 'mux16_1', 'mux32_1']

# Create two side-by-side plots
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Plot 1: Current Flow
axs[0].plot(x, CurrentFlow0, 'o-', color='red', label='Max. Current Flow 0', linewidth=2, markersize=8)
axs[0].plot(x, CurrentFlow1, 's-', color='green', label='Min. Current Flow 1', linewidth=2, markersize=8)

# Add vertical double-headed arrows for safety margin
for i, label in enumerate(x):
    max_val = CurrentFlow0[i]
    min_val = CurrentFlow1[i]
    diff = min_val - max_val
    mid_val = (max_val + min_val) / 2
    if(i!=4):
        axs[0].annotate('', xy=(i, max_val), xytext=(i, min_val),
                        arrowprops=dict(arrowstyle='<->', color='plum', lw=2))
    if(i in (3,4)):
        continue
    axs[0].text(i + 0.1, mid_val, f'{diff:.4f}', color='plum', fontsize=18, va='center')
    
arrow_proxy = Line2D([0], [0], color='plum', linewidth=2)
axs[0].legend([arrow_proxy] + axs[0].get_legend_handles_labels()[0],
              ['Real Safety Margin'] + axs[0].get_legend_handles_labels()[1],
              fontsize=18)

axs[0].set_title('Current Flow Comparison', fontsize=22)
axs[0].set_ylabel('Current (Amps)', fontsize=22)
axs[0].tick_params(axis='x', labelsize=20, rotation=0)
axs[0].tick_params(axis='y', labelsize=20)
axs[0].grid(True, linestyle='--', alpha=0.6)
# axs[0].legend(fontsize=18)
# Annotate path lengths below x-ticks in current graph
for i, label in enumerate(x):
    axs[0].text(i, axs[0].get_ylim()[0] - 0.005, f"L={max_path_length[i]}", 
                ha='center', va='top', fontsize=22, rotation=0)

# Plot 2: Durations
axs[1].plot(x, durations_plot, 'd-', color='blue', label='Execution Time', linewidth=2, markersize=8)
axs[1].set_title('Execution Time Scaling', fontsize=22)
axs[1].set_ylabel('Duration (Scaled Units)', fontsize=22)
axs[1].set_yscale('log')
axs[1].tick_params(axis='x', labelsize=20, rotation=0)
axs[1].tick_params(axis='y', labelsize=20)
axs[1].grid(True, linestyle='--', alpha=0.6)
axs[1].legend(fontsize=18)
# Annotate number of inputs below x-ticks in duration graph
for i, label in enumerate(x):
    axs[1].text(i, axs[1].get_ylim()[0] / 20, f"N={number_of_inputs[i]}", ha='center', va='top', fontsize=22, rotation=0)

# Add common explanatory note below the plots
fig.text(0.0, -0.05, "   L = Path length from source to output in BDD      N = Number of inputs in Boolean expression", 
         ha='left', fontsize=22)

plt.tight_layout()

plt.savefig('current_flow_comparison_mux.png', dpi=300, bbox_inches='tight')
plt.show()
